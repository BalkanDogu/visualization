# %% [markdown]
# # Lesson-1

# %%
import importlib

packages = ['numpy', 'matplotlib', 'pandas', 'scipy', 'PIL', 'requests', 'seaborn']

for package in packages:
    try:
        importlib.import_module(package)
        print(f'{package} is installed.')
    except ImportError:
        print(f'{package} is NOT installed.')
# Out:
# numpy is installed.
# matplotlib is installed.
# pandas is installed.
# scipy is installed.
# PIL is installed.
# requests is installed.
# seaborn is installed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)  # I create x and y values to put those values in the graph. 

fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize = (5,3))  # I but them at bar plot
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize = (5,3)) # I created histogram with same values
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)

ax.set_title("Total growth over time") # I put Title on my graph.
ax.set_ylabel("Total growth")          # For each (x,y) values I gave lable to describe all information.
ax.set_xlabel("Years since start")
# Out:
# Text(0.5, 0, 'Years since start')

# %%
font1 = {"family": "sans-serif", "color": "blue", "size":20}
font2 = {"family": "monospace", "color": "green", "size": 14}

fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)
ax.set_title("Total growth over time", fontdict = font1)
ax.set_ylabel("Total growth", fontdict = font2)
ax.set_xlabel("Years since start", fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize = (5,3))  # we changed the marker shape and color of marker
ax. scatter(x,
            y,
            marker = "+",
            color = "indigo")

# %%
fig, ax = plt.subplots(figsize = (5,3)) ## we just added linestyle and linewidth
ax.plot(x,
        y,
        marker = "*",
        color = "indigo",
        linestyle = "--",
        linewidth = "2")

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
        marker = "*",
        markersize = 12,
        color = "#7425b9",
        linestyle = "--",
        linewidth = "2",
        markeredgecolor = "#fa9359",
        markerfacecolor = "#000000")

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
        marker = "*",
        markersize = 12,
        color = "#7425b9",
        linestyle = "--",
        linewidth = "2",
        markeredgecolor = "#fa9359",
        markerfacecolor = "#000000")

ax.grid(axis = "y")  ## we added a line in y-axis

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y,
        marker = "*",
        markersize = 12,
        color = "#7425b9",
        linestyle = "--",
        linewidth = "2",
        markeredgecolor = "#fa9359",
        markerfacecolor = "#000000")

ax.grid(color = "pink", linewidth = 4, linestyle = "dotted")

# %% [markdown]
# ## Lesson-3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100, 50)
y2 = np.random.randint(0,100, 50)

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1,y2)
# Out:
# [<matplotlib.lines.Line2D at 0x1b31b62bc40>,
#  <matplotlib.lines.Line2D at 0x1b31b62bc70>]

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1, label="person 1")
ax.plot(x, y2, label = "person 2")
ax.legend(loc ="lower right")

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1, label="person 1")
ax.plot(x, y2, label = "person 2")
ax.legend(loc ="lower right",
          frameon = True,
          fontsize = 12,
          ncol = 1,
          shadow = True)

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1, label="person 1")
ax.plot(x, y2, label = "person 2")
ax.legend(loc ="upper left",
          bbox_to_anchor = (1,1))

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc = "lower right")
ax.text(10,95, "This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc = "lower right")
ax.text(10,95, "This value is important!",
        ha = "center",
        color = "red",
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])
# Out:
# (0.0, 10.0, 0.0, 10.0)

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])

ax.text(1,5,"Data: (1,5)", transform = ax.transData)
ax.text(0.5,0.1, "Axes:(0.5,0.1)", transform = ax.transAxes)
ax.text(0.2,0.2,"Figure :(0.2,0.2)", transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, 'Figure :(0.2,0.2)')

# %%
fig, ax= plt.subplots(figsize =(5,3))
ax.scatter(x,y1,label = "person 1")
ax.scatter(x,y2,label = "person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy = (10, 95), xytext = (20,94),
            arrowprops = dict(facecolor = "black",
                              shrink = 0.05))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc ="lower right")

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc ="lower right")

ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc ="lower right")

plt.xticks(rotation = 45, ha = "right", fontsize= 12, font="serif");

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y1, label = "person 1")
ax.scatter(x,y2, label = "person 2")
ax.legend(loc ="lower right")

font1 = {"family":"serif", "color":"indigo"}
plt.xlabel("Shiny New X Axis!", fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75, 50)
y2 = np.random.randint(0,75, 50)
x2 = np.array(["Luffy","Zoro","Nami", "Usopp","Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2,
                               nrows = 1,
                               figsize = (7,3))

ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2,
                               nrows = 1,
                               figsize = (7,3))

ax1.scatter(x1,y1,
            marker = "+",
            color = "indigo")
ax2.bar(x2,y2,
        color = "green")
# Out:
# <BarContainer object of 5 artists>

# %%
fig, (ax1, ax2) = plt.subplots( ncols=2,
                                nrows=1,
                                figsize=(7, 3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
fig.show()
# Out:
# C:\Users\Balkan\AppData\Local\Temp\ipykernel_15852\718339620.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
figsize=(7, 4))
for label, ax in someaxes.items():
    ax.text(0.5, 0.5, f'This is {label!r}',
        fontsize=14,
        ha = 'center',
        transform=ax.transAxes)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
[                                   'ax2', 'ax3']],
                                    figsize=(7, 4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=14 )
plt.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7, 4),
                                    layout = "constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=14 )
plt.show()

# %%
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

fig, ax = plt.subplots(figsize=(7, 3))
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
            color = "red")
ax.errorbar(x,
            y2,
            yerr = y2_sd,
            fmt = "none",
            ecolor= "indigo",
            elinewidth= 4,
            capsize = 6,
            capthick= 4 )
# Out:
# <ErrorbarContainer object of 3 artists>
