# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
from PIL import Image
import requests

# %%
Pip install wordcloud
from wordcloud import WordCloud
# Out:
#   Cell In[5], line 1
#     Pip install wordcloud
#         ^
# SyntaxError: invalid syntax

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data = tips,
             x = "total_bill",
             y = "tip");

# %%
sns.set_style("white")


sns.lineplot(data = tips,
             x = "total_bill",
             y = "tip");

# %%
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')

tipgraph.set(title='Tips vs. Total Bill',
            xlabel='Total Bill ($)',
            ylabel='Tip Amount ($)');

# %%
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip',
                        color = 'hotpink',
                        linestyle = '--',
                        linewidth = 3,
                        marker = 'o',
                        markerfacecolor = 'indigo')

tipgraph.set(title = "Tips vs Total Bill",
             xlabel = "Total Bill ($)",
             ylabel = "Tip Amound ($)");

# %%
tipgraph = sns.scatterplot(data=tips, 
                           x='total_bill',
                           y='tip', 
                           style = 'time', 
                           hue ='day', 
                           palette = ['purple',
                                     'hotpink', 
                                    'deepskyblue',
                                    'yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',
            xlabel='Total Bill ($)',
            ylabel='Tip Amount ($)');

# %%
sns.pairplot(
            data = tips,
            hue = 'day');

# %%
sns.relplot(data= tips,
           x = "total_bill",
           y =  "tip",
           hue = "sex",
           col = "day",
           kind = "scatter",
           col_wrap = 2);

# %%
import plotly.graph_objects as go # 'go' is 'graph objects’

x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar(x=x1, y = y1))

graph.update_layout(title = "Pirate Scores",
                    xaxis_title = "Pirates",
                    yaxis_title = "Score")

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(
                x=x1, 
                y=y1, 
                mode='markers',     # we want points for a scatter plot
                marker=dict(
                            size=15, # point size
                            color='hotpink', # point colour
                            opacity=1, # point transparency/alpha
                            line=dict(width=5, color='purple') # point outline
)))
graph.update_layout(
                    title='Interactive Pirate Plot',
                    xaxis_title='Pirates',
                    yaxis_title='Scores',
                    width=500, height=500)

# %%
# !pip install WordCloud
from wordcloud import WordCloud
# Out:
# Collecting WordCloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from WordCloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from WordCloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from WordCloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->WordCloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->WordCloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    ---------------------------------------- 300.6/300.6 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.9.3

# %%
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
text = " ".join(each for each in df.quote)

wordcloud = WordCloud(background_color = "white",
                      colormap = "inferno").generate(text)

fig, ax = plt.subplots(figsize = (7,3))
ax.imshow(wordcloud,
          interpolation = "bilinear")

ax.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# !pip install matplotlib_venn
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# Requirement already satisfied: matplotlib_venn in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (3.8.4)
# Requirement already satisfied: numpy in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib_venn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\balkan\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib_venn) (1.16.0)

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2([A,B],
                set_labels = ("Fruits", "Pies"), 
                set_colors = ("blue", "red"),
                alpha = 0.5)

diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("n".join(B - A))
